# %% [markdown]
# ---
#
# ## 🧮 Module 5: SciPy
#
# SciPy includes scientific computing utilities like optimization.

# %%
from scipy.optimize import minimize

def f(x):
    return (x - 3)**2

result = minimize(f, x0=0)
print("Min at:", result.x[0])

# %% [markdown]
# ### 📝 Practice
# 1. Minimize the function `(x - 1)**2 + 10` using `scipy.optimize`.
